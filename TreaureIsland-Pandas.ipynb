# %%
# import pandas
import pandas as pd

# %%
# import datasets
cast = pd.read_csv('cast.csv')
titles =  pd.read_csv('titles.csv')
release_dates = pd.read_csv('release_dates.csv')

# %%
cast.tail(2)
# Out:
#                      title  year                         name     type  \
# 3786174       U.S.S.S.S...  2003  Krist?n Andrea ??r?ard?ttir  actress
# 3786175  Bye Bye Blue Bird  1999                 Rosa ? R?gvu  actress
#
#                       character     n
# 3786174  Afgr.dama ? bens?nst??  17.0
# 3786175       Pensionatv?rtinde   NaN

# %%
titles.tail(2)
# Out:
#                          title  year
# 244912               Kanyadaan  1991
# 244913  The Romance of Seville  1929

# %%
release_dates.tail(2)
# Out:
#                           title  year country        date
# 479486  xXx: State of the Union  2005   China  2005-06-17
# 479487  xXx: State of the Union  2005  Greece  2005-06-24

# %% [markdown]
# ---
# ### Question 2)
# How many movies were made between the year 2010 to 2018 (including 2010 and 2018)?

# %%
x = titles[(titles.year <= 2018)&(titles.year >= 2010)]
x.count()
# Out:
# title    74618
# year     74618
# dtype: int64

# %%
titles[titles.title == 'Treasure Island']
# Out:
#                   title  year
# 27895   Treasure Island  1972
# 51170   Treasure Island  1934
# 83406   Treasure Island  1918
# 145487  Treasure Island  1985
# 172577  Treasure Island  1973
# 185859  Treasure Island  1999
# 222075  Treasure Island  1950
# 223039  Treasure Island  1920

# %%
movie_name = 'Treasure Island'
year = 1999

cast[(cast.title == movie_name) & (cast.year == year)].sort_values('n')
# Out:
#                    title  year                  name     type       character  \
# 119689   Treasure Island  1999      Lance (II) Baker    actor           Frank
# 1698413  Treasure Island  1999         Nick Offerman    actor          Samuel
# 219099   Treasure Island  1999        Jonah Blechman    actor        The Body
# 968823   Treasure Island  1999             Pat Healy    actor           Clark
# 3340561  Treasure Island  1999         Suzy Nakamura  actress           Yo-Ji
# 3576899  Treasure Island  1999         Rachel Singer  actress            Anna
# 3057848  Treasure Island  1999    Stephanie Ittleson  actress          Stella
# 2986792  Treasure Island  1999            Daisy Hall  actress           Penny
# 2511526  Treasure Island  1999          Caveh Zahedi    actor          Harold
# 1864302  Treasure Island  1999  Victor Raider-Wexler    actor        Samowitz
# 2049010  Treasure Island  1999           Dolph Scott    actor          Parker
# ...

# %%
actor = 'Tom Cruise'
#years 1980 - 1989

cast[(cast.name == actor)&(cast.year>=1980)&(cast.year<1990)&(cast.n==2)].sort_values('year')
# Out:
#                      title  year        name   type        character    n
# 499308  The Color of Money  1986  Tom Cruise  actor   Vincent Lauria  2.0
# 499303            Rain Man  1988  Tom Cruise  actor  Charlie Babbitt  2.0
